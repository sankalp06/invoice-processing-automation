# %%
import pyodbc

conn_str = (
    "Driver={ODBC Driver 18 for SQL Server};"
    "Server=tcp:sql-server-inv-processing.database.windows.net,1433;"
    "Database=sql-inv-processing;"
    "Uid=invoice;"
    "Pwd=Noematic108$;"
    "Encrypt=yes;"
    "TrustServerCertificate=no;"
    "Connection Timeout=30;"
)

try:
    print("Connecting...")

    conn = pyodbc.connect(conn_str)

    print("Connected successfully!")

    cursor = conn.cursor()

    cursor.execute("SELECT TOP 5 * FROM dbo.invoice_process_log")

    rows = cursor.fetchall()

    print(f"Retrieved {len(rows)} rows")

    for row in rows:
        print(row)

    cursor.close()
    conn.close()

except Exception as e:
    print("Connection failed:")
    print(e)
# Out:
# Connecting...
# Connected successfully!
# Retrieved 0 rows
